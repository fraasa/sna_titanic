# %% [markdown]
# ## Load Data

# %%
import csv
import networkx as nx
import matplotlib.pyplot as plt

# Read nodes from the CSV file
G = nx.Graph()
with open('Graph/nodes.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        G.add_node(row['Id'], label=row['Label'])

# Read edges from the CSV file
with open('Graph/edges.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        G.add_edge(row['Source'], row['Target'], weight=int(row['Weight']))

# %% [markdown]
# ## Plot Graph

# %%
# Set up the plot dimensions
plt.figure(figsize=(36, 36))

# Use the spring layout algorithm for positioning nodes
pos = nx.spring_layout(G)

# Adjust node sizes based on their degrees
node_sizes = [v * 100 for v in dict(G.degree()).values()]

# Adjust edge widths based on their weights
edge_widths = [d['weight'] for _, _, d in G.edges(data=True)]

# Draw the graph
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color='skyblue', alpha=0.6)
nx.draw_networkx_edges(G, pos, width=edge_widths, alpha=0.5)
nx.draw_networkx_labels(G, pos, labels=nx.get_node_attributes(G, 'label'), font_size=10)

plt.title("Titanic Social Network with Weighted Edges")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Simpler Visualizations

# %%
# Set up the plot dimensions
plt.figure(figsize=(15, 15))

# Draw the graph without labels
nx.draw(G, pos, node_color='skyblue', node_size=100, with_labels=False)

plt.title("Titanic Social Network without Labels")
plt.axis("off")
plt.show()

# %%
# Set up the plot dimensions
plt.figure(figsize=(15, 15))

# Adjust node sizes based on their degrees
node_sizes = [v * 100 for v in dict(G.degree()).values()]

# Draw the graph with adjusted node sizes, but without labels or adjusted edge widths
nx.draw(G, pos, node_color='skyblue', node_size=node_sizes, with_labels=False)

plt.title("Titanic Social Network with Node Sizes Adjusted")
plt.axis("off")
plt.show()

# %%
# Set up the plot dimensions
plt.figure(figsize=(15, 15))

# Adjust edge widths based on their weights
edge_widths = [d['weight'] for _, _, d in G.edges(data=True)]

# Draw the graph with adjusted edge widths, but without labels or adjusted node sizes
nx.draw(G, pos, node_color='skyblue', node_size=100, width=edge_widths, with_labels=False)

plt.title("Titanic Social Network with Edge Widths Adjusted")
plt.axis("off")
plt.show()
